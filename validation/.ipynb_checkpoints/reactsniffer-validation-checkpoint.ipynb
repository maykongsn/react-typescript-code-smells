# %%
import numpy as np 
import pandas as pd

df = pd.read_csv("Reactsniffer validation - Responses.csv")
df
# Out:
#    Carimbo de data/hora  \
# 0   22/11/2023 14:40:43
# 1   22/11/2023 14:55:45
# 2   23/11/2023 12:31:22
# 3   23/11/2023 12:49:10
# 4   23/11/2023 13:55:08
# 5   23/11/2023 19:07:27
# 6   24/11/2023 01:24:24
# 7   24/11/2023 15:56:15
# 8   24/11/2023 22:00:01
# 9   24/11/2023 23:17:49
# 10  24/11/2023 23:25:23
# 11  25/11/2023 01:03:44
# 12  25/11/2023 15:49:58
# 13  26/11/2023 17:33:39
# 14  26/11/2023 17:44:02
# 15  26/11/2023 21:57:34
#
#    Após a leitura do termo de Consentimento Livre e Esclarecido  \
# 0   Declaro que concordo em participar da pesquisa...
# 1   Declaro que concordo em participar da pesquisa...
# 2   Declaro que concordo em participar da pesquisa...
# 3   Declaro que concordo em participar da pesquisa...
# 4   Declaro que concordo em participar da pesquisa...
# 5   Declaro que concordo em participar da pesquisa...
# 6   Declaro que concordo em participar da pesquisa...
# 7   Declaro que concordo em participar da pesquisa...
# 8   Declaro que concordo em participar da pesquisa...
# 9   Declaro que concordo em participar da pesquisa...
# 10  Declaro que concordo em participar da pesquisa...
# 11  Declaro que concordo em participar da pesquisa...
# 12  Declaro que concordo em participar da pesquisa...
# 13  Declaro que concordo em participar da pesquisa...
# 14  Declaro que concordo em participar da pesquisa...
# 15  Declaro que concordo em participar da pesquisa...
#
#    Tempo de experiência com o React       Qual o seu curso?  \
# 0                  Entre 1 e 3 anos   Ciência da Computação
# 1                  Entre 1 e 3 anos   Ciência da Computação
# 2                  Entre 1 e 3 anos   Ciência da Computação
# 3                  Entre 1 e 3 anos  Engenharia de Software
# 4                  Entre 1 e 3 anos  Engenharia de Software
# 5                  Entre 1 e 3 anos   Ciência da Computação
# 6                    Menos de 1 ano  Engenharia de Software
# 7                    Menos de 1 ano  Engenharia de Software
# 8                  Entre 1 e 3 anos  Engenharia de Software
# 9                  Entre 3 a 5 anos  Engenharia de Software
# 10                 Entre 1 e 3 anos  Engenharia de Software
# 11                   Menos de 1 ano  Engenharia de Software
# 12                   Menos de 1 ano  Engenharia de Software
# 13                   Menos de 1 ano  Sistemas de Informação
# 14                   Menos de 1 ano  Engenharia de Software
# 15                   Menos de 1 ano  Engenharia de Software
#
#                     UP1                  UP2                  UP3  \
# 0   Concordo totalmente  Concordo totalmente  Concordo totalmente
# 1   Concordo totalmente  Concordo totalmente  Concordo totalmente
# 2              Concordo             Concordo             Concordo
# 3   Concordo totalmente  Concordo totalmente  Concordo totalmente
# 4                Neutro               Neutro               Neutro
# 5   Concordo totalmente  Concordo totalmente             Concordo
# 6              Concordo             Concordo  Concordo totalmente
# 7   Concordo totalmente  Concordo totalmente  Concordo totalmente
# 8   Concordo totalmente  Concordo totalmente  Concordo totalmente
# 9   Concordo totalmente  Concordo totalmente  Concordo totalmente
# 10             Concordo             Concordo  Concordo totalmente
# 11             Concordo             Concordo               Neutro
# 12             Concordo             Concordo               Neutro
# 13             Concordo               Neutro               Neutro
# 14             Concordo             Concordo             Concordo
# 15             Concordo               Neutro             Concordo
#
#                     UP4                  UP5                  UP6  \
# 0   Concordo totalmente  Concordo totalmente  Concordo totalmente
# 1   Concordo totalmente  Concordo totalmente  Concordo totalmente
# 2   Concordo totalmente             Concordo             Concordo
# 3   Concordo totalmente  Concordo totalmente  Concordo totalmente
# 4                Neutro               Neutro             Concordo
# 5              Concordo               Neutro               Neutro
# 6   Concordo totalmente  Concordo totalmente  Concordo totalmente
# 7                Neutro               Neutro               Neutro
# 8   Concordo totalmente  Concordo totalmente  Concordo totalmente
# 9   Concordo totalmente  Concordo totalmente  Concordo totalmente
# 10             Concordo             Concordo             Concordo
# 11  Concordo totalmente             Concordo             Concordo
# 12               Neutro             Concordo               Neutro
# 13             Concordo             Concordo             Concordo
# 14  Concordo totalmente  Concordo totalmente             Concordo
# 15  Concordo totalmente               Neutro               Neutro
#
#                     UP7                  UP8                  UP9  \
# 0   Concordo totalmente  Concordo totalmente  Concordo totalmente
# 1   Concordo totalmente  Concordo totalmente  Concordo totalmente
# 2   Concordo totalmente             Concordo             Concordo
# 3   Concordo totalmente  Concordo totalmente  Concordo totalmente
# 4   Concordo totalmente  Concordo totalmente             Concordo
# 5                Neutro             Concordo  Concordo totalmente
# 6   Concordo totalmente  Concordo totalmente  Concordo totalmente
# 7   Concordo totalmente  Concordo totalmente  Concordo totalmente
# 8   Concordo totalmente  Concordo totalmente  Concordo totalmente
# 9   Concordo totalmente  Concordo totalmente  Concordo totalmente
# 10             Discordo  Concordo totalmente             Concordo
# 11             Concordo             Concordo             Concordo
# 12             Concordo             Concordo             Concordo
# 13             Concordo             Concordo             Concordo
# 14  Concordo totalmente  Concordo totalmente             Concordo
# 15  Concordo totalmente  Concordo totalmente  Concordo totalmente
#
#                    FUP1                 FUP2                 FUP3  \
# 0              Concordo             Concordo             Concordo
# 1              Concordo             Concordo  Concordo totalmente
# 2   Concordo totalmente  Concordo totalmente  Concordo totalmente
# 3              Concordo             Concordo  Concordo totalmente
# 4   Concordo totalmente  Concordo totalmente  Concordo totalmente
# 5              Concordo             Concordo             Concordo
# 6   Concordo totalmente  Concordo totalmente  Concordo totalmente
# 7   Concordo totalmente             Concordo  Concordo totalmente
# 8   Concordo totalmente  Discordo totalmente  Concordo totalmente
# 9   Concordo totalmente  Concordo totalmente  Concordo totalmente
# 10  Concordo totalmente             Discordo  Concordo totalmente
# 11             Concordo               Neutro               Neutro
# 12               Neutro             Discordo             Concordo
# 13             Concordo               Neutro             Concordo
# 14  Concordo totalmente  Concordo totalmente  Concordo totalmente
# 15               Neutro             Discordo             Concordo
#
#                    FUP4                 IUF1                 IUF2
# 0              Concordo  Concordo totalmente             Concordo
# 1              Concordo  Concordo totalmente  Concordo totalmente
# 2   Concordo totalmente               Neutro             Discordo
# 3              Concordo             Concordo             Concordo
# 4   Concordo totalmente               Neutro               Neutro
# 5              Concordo             Concordo               Neutro
# 6              Concordo             Concordo             Concordo
# 7   Concordo totalmente             Concordo               Neutro
# 8   Concordo totalmente             Discordo             Discordo
# 9   Concordo totalmente  Concordo totalmente  Concordo totalmente
# 10             Concordo             Concordo             Concordo
# 11             Concordo             Concordo               Neutro
# 12             Discordo             Discordo             Discordo
# 13             Concordo             Concordo             Concordo
# 14  Concordo totalmente             Concordo             Concordo
# 15               Neutro             Concordo               Neutro

# %%
df = df.drop(['Carimbo de data/hora', 'Após a leitura do termo de Consentimento Livre e Esclarecido', 'Tempo de experiência com o React', 'Qual o seu curso?'], axis=1)

# %%
import pandas as pd
import matplotlib.pyplot as plt

likert_mapping = {
    'Discordo totalmente': 1,
    'Discordo': 2,
    'Neutro': 3,
    'Concordo': 4,
    'Concordo totalmente': 5
}

df_numeric = df.replace(likert_mapping)

mean_by_aspect = df_numeric.mean()

plt.figure(figsize=(10, 6))
mean_by_aspect.plot(kind='bar', color='skyblue')

plt.xlabel('Evaluated Aspects')
plt.ylabel('Average Score')
plt.title('Average Scores by Aspect')

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

map_values = {
    'Concordo totalmente': 'Strongly agree',
    'Concordo': 'Agree',
    'Neutro': 'Neutral',
    'Discordo': 'Disagree',
    'Discordo totalmente': 'Strongly disagree',
}

colors = {
    'Strongly disagree': 'darkred',
    'Disagree': 'indianred',
    'Neutral': 'orange',
    'Agree': 'mediumseagreen',
    'Strongly agree': 'darkgreen'
}

for col in df.columns:
    df[col] = df[col].map(map_values)

cols_sentences = df.loc[:, 'UP1':'UP9']

total_counts = []

for col in cols_sentences.columns:
    responses_count = cols_sentences[col].value_counts().reindex(colors.keys(), fill_value=0)
    total_counts.append(responses_count.values.sum())

plt.figure(figsize=(10, 6))

for i, total_count in enumerate(total_counts):
    left = 0
    for label, color in colors.items():
        count = cols_sentences.iloc[:, i].value_counts().get(label, 0)
        plt.barh(i, count, color=color, left=left, label=label if i == 0 else "", linewidth=0.5)
        
        if count > 0:
            pct = (count / total_count) * 100
            plt.text(left + count / 2, i, f'{pct:.1f}%', ha='center', va='center', color='white', fontsize=10)
        
        left += count if count is not None else 0

plt.xlabel('Number of responses')
plt.ylabel('Sentences')
plt.title('Responses per level of agreement with the sentences')
plt.yticks(range(len(cols_sentences.columns)), cols_sentences.columns)
plt.legend(title='Level of Agreement')
plt.gca().invert_yaxis()

plt.tight_layout()
plt.savefig('perceived_usefulness.png')
plt.show()

# %%
cols_sentences = df.loc[:, 'FUP1':'FUP4']

total_counts = []

for col in cols_sentences.columns:
    responses_count = cols_sentences[col].value_counts().reindex(colors.keys(), fill_value=0)
    total_counts.append(responses_count.values.sum())

plt.figure(figsize=(10, len(cols_sentences.columns) * 1))

for i, total_count in enumerate(total_counts):
    left = 0
    for label, color in colors.items():
        count = cols_sentences.iloc[:, i].value_counts().get(label, 0)
        plt.barh(i, count, color=color, left=left, label=label if i == 0 else "", height=0.8)
        
        if count > 0:
            pct = (count / total_count) * 100
            plt.text(left + count / 2, i, f'{pct:.1f}%', ha='center', va='center', color='white', fontsize=10)
        
        left += count if count is not None else 0

plt.xlabel('Number of responses')
plt.ylabel('Sentences')
plt.title('Responses per level of agreement with the sentences')
plt.yticks(range(len(cols_sentences.columns)), cols_sentences.columns)
plt.legend(title='Level of Agreement', loc='lower right', fontsize='small')
plt.gca().invert_yaxis()

plt.tight_layout()
plt.savefig('perceived_ease_of_use.png')
plt.show()

# %%
cols_sentences = df.loc[:, 'IUF1':'IUF2']

total_counts = []

for col in cols_sentences.columns:
    responses_count = cols_sentences[col].value_counts().reindex(colors.keys(), fill_value=0)
    total_counts.append(responses_count.values.sum())

plt.figure(figsize=(10, len(cols_sentences.columns) * 1.2))

for i, total_count in enumerate(total_counts):
    left = 0
    for label, color in colors.items():
        count = cols_sentences.iloc[:, i].value_counts().get(label, 0)
        plt.barh(i, count, color=color, left=left, label=label if i == 0 else "", height=0.8)
        
        if count > 0:
            pct = (count / total_count) * 100
            plt.text(left + count / 2, i, f'{pct:.1f}%', ha='center', va='center', color='white', fontsize=10)
        
        left += count if count is not None else 0

plt.xlabel('Number of responses')
plt.ylabel('Sentences')
plt.title('Responses per level of agreement with the sentences')
plt.yticks(range(len(cols_sentences.columns)), cols_sentences.columns)
plt.legend(title='Level of Agreement', loc='center right', bbox_to_anchor=(1.25, 0.5), fancybox=True, shadow=True, fontsize='small')

plt.gca().invert_yaxis()

plt.tight_layout()
plt.savefig('self-prediction_of_future_use.png')
plt.show()
